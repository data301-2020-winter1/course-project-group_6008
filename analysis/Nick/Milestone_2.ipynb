# %% [markdown]
# # **Data 301 - Milestone #2**
# ## *Nick Mercuri - 18981167*
# Welcome to my data science project

# %% [markdown]
# # Task #1: Introduction to Markdown

# %% [markdown]
# Markdown code has been included throughout this document.

# %% [markdown]
# # Task #2: Introduction to Git Merges, Branches, and More

# %% [markdown]
# Git Introduction Completion
#
# <img src="Intro_Completion.png" width="800px">

# %% [markdown]
# Git Remotes Completion
#
# <img src="Git_Remotes_Completion.png" width="800px">

# %% [markdown]
# # Task #3: Method Chaining and Python Programs

# %%
import pandas as pd
from Scripts/ import project_functions
# Out:
#   File "<ipython-input-118-6bac0bb784e5>", line 2
#     from Scripts/ import project_functions
#                 ^
# SyntaxError: invalid syntax

# %%
# Chain 1 - Import data and remove any players that did not attend a US University prior to entering the NBA

#Function name: import_and_filter

players_stats_og = pd.read_csv('/Users/Nick/Desktop/Final Project/data/raw/players_stats.csv')

players_stats_university = (
players_stats_og[players_stats_og['Collage'].notnull()]
.reset_index()
.drop(columns=['index']) 
)

players_stats_university
# Out:
#                 Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA  \
# 0           AJ Price            26   324   133   51  137  37.2   15   57
# 1       Aaron Brooks            82  1885   954  344  817  42.1  121  313
# 2       Aaron Gordon            47   797   243   93  208  44.7   13   48
# 3      Adreian Payne            32   740   213   91  220  41.4    1    9
# 4         Al Horford            76  2318  1156  519  965  53.8   11   36
# ..               ...           ...   ...   ...  ...  ...   ...  ...  ...
# 345     Willie Green            52   951   306  118  306  38.6   42  121
# 346  Wilson Chandler            78  2471  1085  418  975  42.9  139  406
# 347     Xavier Henry             9    86    20    3   13  23.1    0    0
# 348      Zach LaVine            77  1902   778  286  677  42.2   57  167
# 349    Zach Randolph            71  2304  1143  454  932  48.7    7   20
#
#       3P%  ...   Age  Birth_Place           Birthdate  \
# ...

# %%
#Chain 2 - Drop unwanted columns, rename columns, and sort by position

#Function name: wrangle_and_process

players_stats_university_wrangled = (
players_stats_university.rename(columns={'Pos' : 'Position'})
.sort_values(by = 'Position', ascending=False)
.reset_index()
.drop(columns = ['BMI', 'Height', 'Weight', 'Birth_Place', 'index'])
)

players_stats_university_wrangled
# Out:
#                  Name  Games Played   MIN   PTS  FGM   FGA   FG%  3PM  3PA  \
# 0      Jamal Crawford            64  1703  1010  332   839  39.6  119  364
# 1        Jimmy Butler            65  2513  1301  421   912  46.2   73  193
# 2           JJ Redick            78  2409  1277  447   938  47.7  200  458
# 3       Kent Bazemore            75  1324   390  141   331  42.6   48  132
# 4    Tim Hardaway Jr.            70  1681   804  279   717  38.9  121  354
# ..                ...           ...   ...   ...  ...   ...   ...  ...  ...
# 345  DeMarcus Cousins            59  2013  1421  498  1066  46.7    2    8
# 346      Steven Adams            70  1771   537  217   399  54.4    0    2
# 347       Tarik Black            63  1195   379  157   273  57.5    0    1
# 348    DeAndre Jordan            82  2820   946  379   534  71.0    1    4
# 349    Meyers Leonard            55   847   327  125   245  51.0   47  112
#
# ...

# %%
# Chain 3 - Create seperate dataframes for each position - Need to remove columns that are not relevant for the position and calculate a weighted rating.

#Function name: filter_by_position

players_stats_university_wrangled_PG = (
players_stats_university_wrangled.loc[players_stats_university_wrangled['Position'] == 'PG']
.sort_values(by = 'Name', ascending=True)
.reset_index()
.drop(columns=['index'])
#.assign(new column that calcuates each player's weighted score)
)

players_stats_university_wrangled_SG = (
players_stats_university_wrangled.loc[players_stats_university_wrangled['Position'] == 'SG']
.sort_values(by = 'Name', ascending=True)
.reset_index()
.drop(columns=['index'])
#.assign(new column that calcuates each player's weighted score)
)

players_stats_university_wrangled_SF = (
players_stats_university_wrangled.loc[players_stats_university_wrangled['Position'] == 'SF']
.sort_values(by = 'Name', ascending=True)
.reset_index()
.drop(columns=['index'])
#.assign(new column that calcuates each player's weighted score)
)

players_stats_university_wrangled_PF = (
players_stats_university_wrangled.loc[players_stats_university_wrangled['Position'] == 'PF']
.sort_values(by = 'Name', ascending=True)
.reset_index()
.drop(columns=['index'])
#.assign(new column that calcuates each player's weighted score)
)

players_stats_university_wrangled_C = (
players_stats_university_wrangled.loc[players_stats_university_wrangled['Position'] == 'C']
.sort_values(by = 'Name', ascending=True)
.reset_index()
.drop(columns=['index'])
#.assign(new column that calcuates each player's weighted score)
)
