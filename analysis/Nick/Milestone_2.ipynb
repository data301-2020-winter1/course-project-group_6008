# %% [markdown]
# # **DATA 301** *Milestone #2*
# ## Group 6008
# Nick Mercuri - 18981167

# %% [markdown]
# # Task 1 - Introduction to Markdown

# %% [markdown]
# Markdown code has been used in different sections throughout this notebook!

# %% [markdown]
# # Task 2 - Introduction to Git Merges, Branches, and More

# %% [markdown]
# <img src="Intro Completion.png" width="800px">

# %% [markdown]
# <img src="Git Remotes Completion.png" width="800px">

# %% [markdown]
# # Task 3 - Method Chaining and Python Programs

# %%
import pandas as pd
import pandas_profiling

# %%
# Remove Columns: 'btc_n_orphaned_blocks', 
# New Columns: Change in Price from Previous Day (How though?)

# %%
df1 = (
        pd.read_csv('/Users/nick/Desktop/Final Project/data/raw/bitcoin_dataset.csv')
        .dropna()
        )
    
df2 = (
        df1.loc[lambda x: x['btc_market_price']>0]
        .reset_index()
        .drop(columns =['index', 'btc_n_orphaned_blocks','btc_estimated_transaction_volume', 
                        'btc_cost_per_transaction_percent', 'btc_n_transactions_excluding_popular', 'btc_n_transactions_excluding_chains_longer_than_100']) # Remove some more
          )

df2
# Out:
#                      Date  btc_market_price  btc_total_bitcoins  \
# 0     2010-08-17 00:00:00          0.076900           3744250.0
# 1     2010-08-18 00:00:00          0.074000           3750900.0
# 2     2010-08-19 00:00:00          0.068800           3757900.0
# 3     2010-08-20 00:00:00          0.066700           3766250.0
# 4     2010-08-21 00:00:00          0.066899           3775450.0
# ...                   ...               ...                 ...
# 2719  2018-02-16 00:00:00      10127.161667          16869150.0
# 2720  2018-02-17 00:00:00      10841.991667          16871012.5
# 2721  2018-02-18 00:00:00      10503.298333          16873037.5
# 2722  2018-02-19 00:00:00      11110.965000          16875062.5
# 2723  2018-02-20 00:00:00      11390.391667          16876825.0
#
#       btc_market_cap  btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0       2.879328e+05      9.230018e+02         1.000000            0.000959
# ...
