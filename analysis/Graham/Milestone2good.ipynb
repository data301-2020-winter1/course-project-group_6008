# %% [markdown]
# ## Task 1
# **Demonstrating bold text**
# *With some italic text*
# 1. One
# 2. Two

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/raw/players_stats.csv')
def load_and_clean(url_or_path_to_csv_file):
    df = pd.read_csv(url_or_path_to_csv_file)
    df1 = df.drop(columns = ['BMI','Weight','Team','Birth_Place','Birthdate','Age'])
    df2 = df1['Experience'].str.replace('R','0')
    df1['Experience'] = df2
    return df1
load_and_clean('../../data/raw/players_stats.csv')
# Out:
#               Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0         AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1     Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2     Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3    Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4       Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
# ..             ...           ...   ...   ...  ...  ...   ...  ...  ...   ...
# 485   Xavier Henry             9    86    20    3   13  23.1    0    0   0.0
# 486    Zach LaVine            77  1902   778  286  677  42.2   57  167  34.1
# 487  Zach Randolph            71  2304  1143  454  932  48.7    7   20  35.0
# 488  Zaza Pachulia            73  1730   606  240  529  45.4    0    3   0.0
# 489   Zoran Dragic            16    75    28   11   30  36.7    3   14  21.4
#
# ...

# %% [markdown]
# ## Task 3

# %%
def load_and_process_data(url_or_path_to_csv_file):

    df1 = (pd.read_csv(url_or_path_to_csv_file)
          .drop(columns = ['BMI','Weight','Team','Birth_Place','Birthdate','Age'])
          .dropna()
          .replace('R', '0')
         )
    return df1
load_and_process_data('../../data/raw/players_stats.csv')
# Out:
#                 Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA  \
# 0           AJ Price            26   324   133   51  137  37.2   15   57
# 1       Aaron Brooks            82  1885   954  344  817  42.1  121  313
# 2       Aaron Gordon            47   797   243   93  208  44.7   13   48
# 3      Adreian Payne            32   740   213   91  220  41.4    1    9
# 4         Al Horford            76  2318  1156  519  965  53.8   11   36
# ..               ...           ...   ...   ...  ...  ...   ...  ...  ...
# 483     Willie Green            52   951   306  118  306  38.6   42  121
# 484  Wilson Chandler            78  2471  1085  418  975  42.9  139  406
# 485     Xavier Henry             9    86    20    3   13  23.1    0    0
# 486      Zach LaVine            77  1902   778  286  677  42.2   57  167
# 487    Zach Randolph            71  2304  1143  454  932  48.7    7   20
#
#       3P%  ...  BLK  TOV   PF   EFF  AST/TOV  STL/TOV  \
# ...

# %%
#Imported functions
from scripts.project_functions import load_and_process
df1 = load_and_process('../../data/raw/players_stats.csv')
df1
# Out:
#                      Name  Games Played   MIN  PTS  FGM  FGA   FG%  3PM  3PA  \
# 426       Shawne Williams            63  1087  341  121  300  40.3   64  178
# 414       Sean Kilpatrick             4    72   22    7   20  35.0    4   13
# 199        JaMychal Green            24   164   62   27   47  57.4    0    6
# 197  James Michael McAdoo            15   137   62   24   44  54.5    0    0
# 193       James Ennis III            62  1051  312  101  247  40.9   31   95
# ..                    ...           ...   ...  ...  ...  ...   ...  ...  ...
# 389        Raymond Felton            29   281  108   43  106  40.6   10   34
# 325       Marvin Williams            78  2035  577  210  495  42.4   95  265
# 205          Jarrett Jack            80  2241  957  359  817  43.9   39  146
# 206         Jason Maxiell            61   878  203   81  192  42.2    0    0
# 49           Brandon Bass            82  1929  866  344  683  50.4    9   32
#
# ...

# %% [markdown]
# ## Task 4

# %%
df1.shape
##Shape of dataset
# Out:
# (350, 28)

# %%
df1.head(5)
##First 5
# Out:
#                      Name  Games Played   MIN  PTS  FGM  FGA   FG%  3PM  3PA  \
# 426       Shawne Williams            63  1087  341  121  300  40.3   64  178
# 414       Sean Kilpatrick             4    72   22    7   20  35.0    4   13
# 199        JaMychal Green            24   164   62   27   47  57.4    0    6
# 197  James Michael McAdoo            15   137   62   24   44  54.5    0    0
# 193       James Ennis III            62  1051  312  101  247  40.9   31   95
#
#       3P%  ...  BLK  TOV   PF  EFF  AST/TOV  STL/TOV  \
# 426  36.0  ...   21   30  135  383     1.47     0.83
# 414  30.8  ...    0    2    3   20     2.00     1.50
# 199   0.0  ...    5   14   25   85     0.29     0.36
# 197   0.0  ...    9    6   21   78     0.33     0.83
# 193  32.6  ...   17   39   89  378     1.23     0.64
#
#                                      Collage  Experience  Height  Pos
# 426              Western Michigan University           0   207.5   PF
# ...

# %%
df1.columns
##names of columns
# Out:
# Index(['Name', 'Games Played', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'EFF', 'AST/TOV', 'STL/TOV', 'Collage', 'Experience',
#        'Height', 'Pos'],
#       dtype='object')

# %%
df1.describe()
# Out:
#        Games Played          MIN          PTS         FGM          FGA  \
# count    350.000000   350.000000   350.000000  350.000000   350.000000
# mean      52.517143  1207.868571   495.825714  185.117143   416.214286
# std       24.227160   835.251245   428.888777  157.370533   341.570395
# min        1.000000     3.000000     0.000000    0.000000     0.000000
# 25%       33.000000   418.500000   135.250000   51.250000   124.000000
# 50%       60.000000  1192.000000   397.500000  149.000000   349.000000
# 75%       73.000000  1905.750000   779.000000  290.250000   655.500000
# max       82.000000  2981.000000  2217.000000  659.000000  1470.000000
#
#               FG%         3PM         3PA         3P%         FTM  ...  \
# count  350.000000  350.000000  350.000000  350.000000  350.000000  ...
# mean    42.562857   41.548571  117.894286   26.019429   84.042857  ...
# std      9.008060   50.338643  131.781067   14.944837   91.581963  ...
# ...

# %%
tvp = (df1[['Name', 'PTS', 'Experience']]
       .dropna() 
      )
tvp
#Taking a DataFrame of only name, points, and time in league (experience)
# Out:
#                      Name  PTS Experience
# 426       Shawne Williams  341          0
# 414       Sean Kilpatrick   22          0
# 199        JaMychal Green   62          0
# 197  James Michael McAdoo   62          0
# 193       James Ennis III  312          0
# ..                    ...  ...        ...
# 389        Raymond Felton  108          9
# 325       Marvin Williams  577          9
# 205          Jarrett Jack  957          9
# 206         Jason Maxiell  203          9
# 49           Brandon Bass  866          9
#
# [350 rows x 3 columns]

# %%
grp = (tvp.groupby('Experience')
         .mean(['PTS'])
         .reset_index()
         .sort_values(by=['PTS'], ascending = True)
        )
grp
#Each level of experience grouped and averaged PTS in season
# Out:
#    Experience          PTS
# 0           0   187.607143
# 7          15   242.333333
# 4          12   343.300000
# 6          14   379.666667
# 1           1   382.897959
# 8          16   426.333333
# 17          9   465.750000
# 10          2   485.102564
# 2          10   509.384615
# 15          7   524.150000
# 3          11   589.428571
# 12          4   634.680000
# 14          6   668.320000
# 13          5   685.903226
# 11          3   690.266667
# 16          8   729.461538
# 5          13   909.666667
# 9          17  1070.000000

# %%
plt.figure(figsize=(15, 7))
sns.scatterplot(data=grp,
                x='Experience',
                y='PTS'
                )
plt.xlabel('Experience (Years in NBA)')
plt.ylabel('Points in Season')
plt.title('Points Versus Years of Experience in NBA')
# Out:
# Text(0.5, 1.0, 'Points Versus Years of Experience in NBA')

# %%
plt.figure(figsize=(15, 7))
sns.violinplot(data = tvp,
              x = 'Experience',
              y = 'PTS'
              )
#Distribution of each experience level PTS
# Out:
# <AxesSubplot:xlabel='Experience', ylabel='PTS'>

# %%
top = (tvp.sort_values(by='PTS', ascending = False)
          .head(5))
top
#experience of top 5 point getters
# Out:
#                   Name   PTS Experience
# 194       James Harden  2217          5
# 433      Stephen Curry  1900          5
# 91      Damian Lillard  1720          2
# 281      Klay Thompson  1668          3
# 292  LaMarcus Aldridge  1661          8

# %%
plt.figure(figsize=(15, 7))
sns.set_context("talk")
sns.scatterplot(data = top,
               x = 'Name',
               y = 'PTS',
               size = 'Experience',
               hue = 'Experience')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='PTS'>

# %% [markdown]
# Top 10 players by efficeincy, what schools did they attend?

# %%
bmi = (df[['BMI', 'EFF']])
bmi
# Out:
#            BMI   EFF
# 0    23.798393   110
# 1    22.361111   791
# 2    24.142661   318
# 3    25.377751   244
# 4    26.234384  1530
# ..         ...   ...
# 485  26.035503     7
# 486  22.951594   720
# 487  28.532236  1422
# 488  28.218900   929
# 489  24.287401    17
#
# [490 rows x 2 columns]

# %%
plt.figure(figsize=(15, 7))
sns.barplot(data = bmi, x = "BMI", y = "EFF")
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='EFF'>

# %%
bmi_count = (bmi["BMI"])
bmi_count
# Out:
# 0      23.798393
# 1      22.361111
# 2      24.142661
# 3      25.377751
# 4      26.234384
#          ...
# 485    26.035503
# 486    22.951594
# 487    28.532236
# 488    28.218900
# 489    24.287401
# Name: BMI, Length: 490, dtype: float64

# %%
plt.figure(figsize=(15, 7))
sns.histplot(bmi_count)
plt.ylabel("Number of Players in NBA")
# Out:
# Text(0, 0.5, 'Number of Players in NBA')
